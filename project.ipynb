# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Read the data
us101sb_20191019 = pd.read_csv('Group 2 US101SB/US101SB_10-19-2019.csv')
us101sb_20191019.head()
# Out:
#               date  station_ID  vol_1   occ_1  speed_1  vol_2   occ_2  \
# 0  10/19/2019 0:00      402005      0  0.0000        0      0  0.0000
# 1  10/19/2019 0:00      405389      0  0.0000        0      0  0.0000
# 2  10/19/2019 0:00      405390      0  0.0000        0      5  0.0306
# 3  10/19/2019 0:00      405394      0  0.0000        0      0  0.0000
# 4  10/19/2019 0:00      405395      1  0.0056       78      1  0.0078
#
#    speed_2  vol_3   occ_3  speed_3  vol_4  occ_4  speed_4  vol_5  occ_5  \
# 0        0    NaN     NaN      NaN    NaN    NaN      NaN    NaN    NaN
# 1        0    0.0  0.0000      0.0    0.0    0.0      0.0    NaN    NaN
# 2       78    3.0  0.0206     71.0    0.0    0.0      0.0    NaN    NaN
# 3        0    0.0  0.0000      0.0    NaN    NaN      NaN    NaN    NaN
# 4       60    0.0  0.0000      0.0    NaN    NaN      NaN    NaN    NaN
#
#    speed_5
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN

# %%
# Inspect data of specific station id
filtered_df = us101sb_20191019[us101sb_20191019['station_ID'] == 405395]
filtered_df.head()
# Out:
#                 date  station_ID  vol_1   occ_1  speed_1  vol_2   occ_2  \
# 4    10/19/2019 0:00      405395      1  0.0056       78      1  0.0078
# 149  10/19/2019 0:00      405395      0  0.0000        0      5  0.0339
# 294  10/19/2019 0:01      405395      1  0.0067       71      2  0.0139
# 439  10/19/2019 0:01      405395      0  0.0000        0      1  0.0228
# 584  10/19/2019 0:02      405395      1  0.0067       71      1  0.0067
#
#      speed_2  vol_3   occ_3  speed_3  vol_4  occ_4  speed_4  vol_5  occ_5  \
# 4         60    0.0  0.0000      0.0    NaN    NaN      NaN    NaN    NaN
# 149       60    4.0  0.0289     65.0    NaN    NaN      NaN    NaN    NaN
# 294       60    2.0  0.0378     60.0    NaN    NaN      NaN    NaN    NaN
# 439       56    2.0  0.0206     71.0    NaN    NaN      NaN    NaN    NaN
# 584       60    2.0  0.0117     78.0    NaN    NaN      NaN    NaN    NaN
#
#      speed_5
# 4        NaN
# 149      NaN
# 294      NaN
# 439      NaN
# 584      NaN

# %%
# Filter the data for station_ID == 405395
# station_data = filtered_df[filtered_df['station_ID'] == 405395]

# Convert the 'date' column to datetime format
station_data['date'] = pd.to_datetime(station_data['date'])

# Plot the data as a dot plot
plt.figure(figsize=(12, 6))
plt.scatter(station_data['date'], station_data['speed_1'], label='Speed 1', color='blue', s=10)
plt.xlabel('Date')
plt.ylabel('Speed 1')
plt.title('Speed 1 over Time for Station ID 405395')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Convert the 'date' column to datetime format if not already done
us101sb_20191019['date'] = pd.to_datetime(us101sb_20191019['date'])

# Create the scatter plot
plt.figure(figsize=(12, 6))
scatter = plt.scatter(us101sb_20191019['date'], us101sb_20191019['station_ID'], c=us101sb_20191019['speed_1'], cmap='viridis', s=10)
plt.colorbar(scatter, label='Speed 1')
plt.xlabel('Date')
plt.ylabel('Station ID')
plt.title('Scatter Plot of Station ID over Date with Speed 1 as Color')
plt.grid(True)
plt.show()
